# %% [markdown]
# # Project 1: Gradient-based Algorithms and Differentiable Programming
#
#
# ## 1. Introduction
# Consider a simple formulation of rocket landing where the rocket state $x(t)$ is represented by its distance to the ground $d(t)$ and its velocity $v(t)$, i.e., $x(t) = [d(t), v(t)]^T$, where $t$ specifies time. The control input of the rocket is its acceleration $a(t)$. The discrete-time dynamics follows
#
# $$
# \begin{aligned}
# d(t+1) = d(t) + v(t) \Delta t, \\
# v(t+1) = v(t) + a(t) \Delta t,
# \end{aligned}
# $$
#
# where $\Delta t$ is a time interval. Further, let the closed-loop controller be
#
# $$
# a(t) = f_{\theta}(x(t))
# $$
#
# where $f_{\theta}(\cdot)$ is a neural network with parameters $\theta$, which are to be determined through optimization.
#
# For each time step, we assign a loss as a function of the control input and the state: $l(x(t),a(t))$. In this example, we will simply set $l(x(t),a(t))=0$ for all $t=1,...,T-1$, where $T$ is the final time step, and $l(x(T),a(T)) = ||x(T)||^2 = d(T)^2 + v(T)^2$. This loss encourages the rocket to reach $d(T)=0$ and $v(T)=0$, which are proper landing conditions.
#
# The optimization problem is now formulated as
#
# $$
# \begin{aligned}
# \min_{\theta} \quad & ||x(T)||^2 \\
# \quad & d(t+1) = d(t) + v(t) \Delta t, \\
# \quad & v(t+1) = v(t) + a(t) \Delta t, \\
# \quad & a(t) = f_{\theta}(x(t)), ~\forall t=1,...,T-1
# \end{aligned}
# $$
#
# While this problem is constrained, it is easy to see that the objective function can be expressed as a function of $x(T-1) and a(T-1)$, where $x(T-1)$ as a function of $x(T-2)$ and $a(T-2)$, and so on. Thus it is essentially an unconstrained problem with respect to $\theta$.
#
# In the following, we code this problem up with [PyTorch](https://pytorch.org/), which allows us to only build the forward pass of the loss (i.e., how we move from $x(1)$ to $x(2)$ and all the way to $x(T)$) and automatically get the gradient $\nabla_{\theta} l(x(T),a(T))$.
#
# ---
#
# ## 2. Sample Code
#
# Before you start, please make sure you install the PyTorch package in Python. If you are using Pycharm, you can do so through *setting*->*Project: Your Project Name*->*Project Interpreter*->*Install (the little plus sign to the right of the window)*.

# %%
# overhead
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import logging
import math
import random
import numpy as np
import time
import torch as t
import torch.nn as nn
from torch import optim
from torch.nn import utils
import matplotlib.pyplot as plt

logger = logging.getLogger(__name__)

# %%
# environment parameters

FRAME_TIME = 0.1  # time interval
GRAVITY_ACCEL = 0.12  # gravity constant
BOOST_ACCEL = 0.18  # thrust constant
RHO = 1.225
S = 0.18
DRAG_COEFF = 0.7
pe = 0.1
po = 7
Ae = 0.5

graph_1_x_axis = []
graph_2_x_axis = []
graph_1_y_axis = []
graph_2_y_axis = []

# # the following parameters are not being used in the sample code
# PLATFORM_WIDTH = 0.25  # landing platform width
# PLATFORM_HEIGHT = 0.06  # landing platform height
# ROTATION_ACCEL = 20  # rotation constant

# %%
# define system dynamics
# Notes: 
# 0. You only need to modify the "forward" function
# 1. All variables in "forward" need to be PyTorch tensors.
# 2. All math operations in "forward" has to be differentiable, e.g., default PyTorch functions.
# 3. Do not use inplace operations, e.g., x += 1. Please see the following section for an example that does not work.

class Dynamics(nn.Module):

    def __init__(self):
        super(Dynamics, self).__init__()

    @staticmethod
    def forward(state, action):

        """
        action: thrust or no thrust
        state[0] = y
        state[1] = y_dot
        
        """
        
        # Apply gravity
        # Note: Here gravity is used to change velocity which is the second element of the state vector
        # Normally, we would do x[1] = x[1] + gravity * delta_time
        # but this is not allowed in PyTorch since it overwrites one variable (x[1]) that is part of the computational graph to be differentiated.
        # Therefore, I define a tensor dx = [0., gravity * delta_time], and do x = x + dx. This is allowed... 
        delta_state_gravity = t.tensor([0., GRAVITY_ACCEL * FRAME_TIME])
        
        # Thrust
        # Note: Same reason as above. Need a 2-by-1 tensor.
        delta_state = BOOST_ACCEL * FRAME_TIME * t.tensor([0., -1.]) * action
        delta_state_gravity = t.tensor([0.,GRAVITY_ACCEL*FRAME_TIME])
        delta_state_drag = t.tensor([0., -0.5*RHO*S*DRAG_COEFF*FRAME_TIME*(state.detach().clone()[1]**2)])
        delta_state = BOOST_ACCEL * FRAME_TIME * delta_state_drag * t.tensor([0., -1.]) * action
        
        
        
        

        # Update velocity
        state = state + delta_state + delta_state_gravity 
        
        delta_mass =  (delta_state - (pe-po)*Ae) / state
        
        
        # Update state
        # Note: Same as above. Use operators on matrices/tensors as much as possible. Do not use element-wise operators as they are considered inplace.
        step_mat = t.tensor([[1., FRAME_TIME],
                            [0., 1.]])
        state = t.matmul(step_mat, state)
        
                
        print(state)
        #graph_1_x_axis.append(delta_mass[0].detach().numpy())
        #graph_1_y_axis.append(delta_state[0].detach().numpy())
        
        
        #plt.plot(delta_mass.detach().numpy(), state.detach().numpy())
        return state

# %%
# a deterministic controller
# Note:
# 0. You only need to change the network architecture in "__init__"
# 1. nn.Sigmoid outputs values from 0 to 1, nn.Tanh from -1 to 1
# 2. You have all the freedom to make the network wider (by increasing "dim_hidden") or deeper (by adding more lines to nn.Sequential)
# 3. Always start with something simple

class Controller(nn.Module):

    def __init__(self, dim_input, dim_hidden, dim_output):
        """
        dim_input: # of system states
        dim_output: # of actions
        dim_hidden: up to you
        """
        super(Controller, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(dim_input, dim_hidden),
            nn.Tanh(),
            nn.Linear(dim_hidden, dim_output),
            # You can add more layers here
            nn.Sigmoid()
        )

    def forward(self, state):
        action = self.network(state)
        return action

# %%
# the simulator that rolls out x(1), x(2), ..., x(T)
# Note:
# 0. Need to change "initialize_state" to optimize the controller over a distribution of initial states
# 1. self.action_trajectory and self.state_trajectory stores the action and state trajectories along time

class Simulation(nn.Module):

    def __init__(self, controller, dynamics, T):
        super(Simulation, self).__init__()
        self.state = self.initialize_state()
        self.controller = controller
        self.dynamics = dynamics
        self.T = T
        self.action_trajectory = []
        self.state_trajectory = []

    def forward(self, state):
        self.action_trajectory = []
        self.state_trajectory = []
        for _ in range(T):
            action = self.controller.forward(state)
            state = self.dynamics.forward(state, action)
            self.action_trajectory.append(action)
            self.state_trajectory.append(state)
        return self.error(state)

    @staticmethod
    def initialize_state():
        state = [1., 0.]  # TODO: need batch of initial states
        return t.tensor(state, requires_grad=False).float()

    def error(self, state):
        return state[0]**2 + state[1]**2

# %%
# set up the optimizer
# Note:
# 0. LBFGS is a good choice if you don't have a large batch size (i.e., a lot of initial states to consider simultaneously)
# 1. You can also try SGD and other momentum-based methods implemented in PyTorch
# 2. You will need to customize "visualize"
# 3. loss.backward is where the gradient is calculated (d_loss/d_variables)
# 4. self.optimizer.step(closure) is where gradient descent is done

class Optimize:
    def __init__(self, simulation):
        self.simulation = simulation
        self.parameters = simulation.controller.parameters()
        self.optimizer = optim.LBFGS(self.parameters, lr=0.01)

    def step(self):
        def closure():
            loss = self.simulation(self.simulation.state)
            self.optimizer.zero_grad()
            loss.backward()
            return loss
        self.optimizer.step(closure)
        return closure()
    
    def train(self, epochs):
        for epoch in range(epochs):
            loss = self.step()
            print('[%d] loss: %.3f' % (epoch + 1, loss))
            self.visualize()

    def visualize(self):
        data = np.array([self.simulation.state_trajectory[i].detach().numpy() for i in range(self.simulation.T)])
        x = data[:, 0]
        y = data[:, 1]
        plt.plot(x, y)
        plt.show()

# %%
# Now it's time to run the code!

T = 100  # number of time steps
dim_input = 2  # state space dimensions
dim_hidden = 6  # latent dimensions
dim_output = 1  # action space dimensions
d = Dynamics()  # define dynamics
c = Controller(dim_input, dim_hidden, dim_output)  # define controller
s = Simulation(c, d, T)  # define simulation
o = Optimize(s)  # define optimizer
o.train(50)  # solve the optimization problem
#plt.plot( graph_1_x_axis, graph_1_y_axis )
#plt.show()
#plt.plot(graph_2_x_axis, graph_2_y_axis )
#plt.show()
# Out:
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3361], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3481], grad_fn=<MvBackward>)
# tensor([1.5581, 0.3601], grad_fn=<MvBackward>)
# tensor([1.5953, 0.3721], grad_fn=<MvBackward>)
# tensor([1.6337, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9842, 0.4802], grad_fn=<MvBackward>)
# tensor([2.0334, 0.4922], grad_fn=<MvBackward>)
# tensor([2.0838, 0.5042], grad_fn=<MvBackward>)
# tensor([2.1354, 0.5162], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5282], grad_fn=<MvBackward>)
# tensor([2.2423, 0.5402], grad_fn=<MvBackward>)
# tensor([2.2975, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3539, 0.5643], grad_fn=<MvBackward>)
# tensor([2.4115, 0.5763], grad_fn=<MvBackward>)
# tensor([2.4704, 0.5883], grad_fn=<MvBackward>)
# tensor([2.5304, 0.6003], grad_fn=<MvBackward>)
# tensor([2.5916, 0.6123], grad_fn=<MvBackward>)
# tensor([2.6541, 0.6244], grad_fn=<MvBackward>)
# tensor([2.7177, 0.6364], grad_fn=<MvBackward>)
# tensor([2.7825, 0.6484], grad_fn=<MvBackward>)
# tensor([2.8486, 0.6604], grad_fn=<MvBackward>)
# tensor([2.9158, 0.6724], grad_fn=<MvBackward>)
# tensor([2.9843, 0.6845], grad_fn=<MvBackward>)
# tensor([3.0539, 0.6965], grad_fn=<MvBackward>)
# tensor([3.1248, 0.7085], grad_fn=<MvBackward>)
# tensor([3.1968, 0.7206], grad_fn=<MvBackward>)
# tensor([3.2701, 0.7326], grad_fn=<MvBackward>)
# tensor([3.3446, 0.7446], grad_fn=<MvBackward>)
# tensor([3.4202, 0.7566], grad_fn=<MvBackward>)
# tensor([3.4971, 0.7687], grad_fn=<MvBackward>)
# tensor([3.5752, 0.7807], grad_fn=<MvBackward>)
# tensor([3.6544, 0.7927], grad_fn=<MvBackward>)
# tensor([3.7349, 0.8048], grad_fn=<MvBackward>)
# tensor([3.8166, 0.8168], grad_fn=<MvBackward>)
# tensor([3.8995, 0.8289], grad_fn=<MvBackward>)
# tensor([3.9836, 0.8409], grad_fn=<MvBackward>)
# tensor([4.0689, 0.8529], grad_fn=<MvBackward>)
# tensor([4.1554, 0.8650], grad_fn=<MvBackward>)
# tensor([4.2431, 0.8770], grad_fn=<MvBackward>)
# tensor([4.3320, 0.8891], grad_fn=<MvBackward>)
# tensor([4.4221, 0.9011], grad_fn=<MvBackward>)
# tensor([4.5134, 0.9132], grad_fn=<MvBackward>)
# tensor([4.6059, 0.9252], grad_fn=<MvBackward>)
# tensor([4.6996, 0.9373], grad_fn=<MvBackward>)
# tensor([4.7946, 0.9493], grad_fn=<MvBackward>)
# tensor([4.8907, 0.9614], grad_fn=<MvBackward>)
# tensor([4.9880, 0.9734], grad_fn=<MvBackward>)
# tensor([5.0866, 0.9855], grad_fn=<MvBackward>)
# tensor([5.1863, 0.9975], grad_fn=<MvBackward>)
# tensor([5.2873, 1.0096], grad_fn=<MvBackward>)
# tensor([5.3895, 1.0216], grad_fn=<MvBackward>)
# tensor([5.4928, 1.0337], grad_fn=<MvBackward>)
# tensor([5.5974, 1.0458], grad_fn=<MvBackward>)
# tensor([5.7032, 1.0578], grad_fn=<MvBackward>)
# tensor([5.8102, 1.0699], grad_fn=<MvBackward>)
# tensor([5.9184, 1.0820], grad_fn=<MvBackward>)
# tensor([6.0278, 1.0940], grad_fn=<MvBackward>)
# tensor([6.1384, 1.1061], grad_fn=<MvBackward>)
# tensor([6.2502, 1.1182], grad_fn=<MvBackward>)
# tensor([6.3632, 1.1303], grad_fn=<MvBackward>)
# tensor([6.4775, 1.1423], grad_fn=<MvBackward>)
# tensor([6.5929, 1.1544], grad_fn=<MvBackward>)
# tensor([6.7096, 1.1665], grad_fn=<MvBackward>)
# tensor([6.8274, 1.1786], grad_fn=<MvBackward>)
# tensor([6.9465, 1.1906], grad_fn=<MvBackward>)
# tensor([7.0667, 1.2027], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3361], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3481], grad_fn=<MvBackward>)
# tensor([1.5581, 0.3601], grad_fn=<MvBackward>)
# tensor([1.5953, 0.3721], grad_fn=<MvBackward>)
# tensor([1.6337, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9842, 0.4802], grad_fn=<MvBackward>)
# tensor([2.0334, 0.4922], grad_fn=<MvBackward>)
# tensor([2.0838, 0.5042], grad_fn=<MvBackward>)
# tensor([2.1354, 0.5162], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5282], grad_fn=<MvBackward>)
# tensor([2.2423, 0.5402], grad_fn=<MvBackward>)
# tensor([2.2975, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3539, 0.5643], grad_fn=<MvBackward>)
# tensor([2.4115, 0.5763], grad_fn=<MvBackward>)
# tensor([2.4704, 0.5883], grad_fn=<MvBackward>)
# tensor([2.5304, 0.6003], grad_fn=<MvBackward>)
# tensor([2.5916, 0.6123], grad_fn=<MvBackward>)
# tensor([2.6541, 0.6244], grad_fn=<MvBackward>)
# tensor([2.7177, 0.6364], grad_fn=<MvBackward>)
# tensor([2.7825, 0.6484], grad_fn=<MvBackward>)
# tensor([2.8486, 0.6604], grad_fn=<MvBackward>)
# tensor([2.9158, 0.6724], grad_fn=<MvBackward>)
# tensor([2.9843, 0.6845], grad_fn=<MvBackward>)
# tensor([3.0539, 0.6965], grad_fn=<MvBackward>)
# tensor([3.1248, 0.7085], grad_fn=<MvBackward>)
# tensor([3.1968, 0.7205], grad_fn=<MvBackward>)
# tensor([3.2701, 0.7326], grad_fn=<MvBackward>)
# tensor([3.3446, 0.7446], grad_fn=<MvBackward>)
# tensor([3.4202, 0.7566], grad_fn=<MvBackward>)
# tensor([3.4971, 0.7687], grad_fn=<MvBackward>)
# tensor([3.5752, 0.7807], grad_fn=<MvBackward>)
# tensor([3.6544, 0.7927], grad_fn=<MvBackward>)
# tensor([3.7349, 0.8048], grad_fn=<MvBackward>)
# tensor([3.8166, 0.8168], grad_fn=<MvBackward>)
# tensor([3.8995, 0.8289], grad_fn=<MvBackward>)
# tensor([3.9836, 0.8409], grad_fn=<MvBackward>)
# tensor([4.0689, 0.8529], grad_fn=<MvBackward>)
# tensor([4.1554, 0.8650], grad_fn=<MvBackward>)
# tensor([4.2431, 0.8770], grad_fn=<MvBackward>)
# tensor([4.3320, 0.8891], grad_fn=<MvBackward>)
# tensor([4.4221, 0.9011], grad_fn=<MvBackward>)
# tensor([4.5134, 0.9132], grad_fn=<MvBackward>)
# tensor([4.6059, 0.9252], grad_fn=<MvBackward>)
# tensor([4.6996, 0.9373], grad_fn=<MvBackward>)
# tensor([4.7946, 0.9493], grad_fn=<MvBackward>)
# tensor([4.8907, 0.9614], grad_fn=<MvBackward>)
# tensor([4.9880, 0.9734], grad_fn=<MvBackward>)
# tensor([5.0866, 0.9855], grad_fn=<MvBackward>)
# tensor([5.1863, 0.9975], grad_fn=<MvBackward>)
# tensor([5.2873, 1.0096], grad_fn=<MvBackward>)
# tensor([5.3895, 1.0216], grad_fn=<MvBackward>)
# tensor([5.4928, 1.0337], grad_fn=<MvBackward>)
# tensor([5.5974, 1.0458], grad_fn=<MvBackward>)
# tensor([5.7032, 1.0578], grad_fn=<MvBackward>)
# tensor([5.8102, 1.0699], grad_fn=<MvBackward>)
# tensor([5.9184, 1.0820], grad_fn=<MvBackward>)
# tensor([6.0278, 1.0940], grad_fn=<MvBackward>)
# tensor([6.1384, 1.1061], grad_fn=<MvBackward>)
# tensor([6.2502, 1.1182], grad_fn=<MvBackward>)
# tensor([6.3632, 1.1302], grad_fn=<MvBackward>)
# tensor([6.4775, 1.1423], grad_fn=<MvBackward>)
# tensor([6.5929, 1.1544], grad_fn=<MvBackward>)
# tensor([6.7095, 1.1665], grad_fn=<MvBackward>)
# tensor([6.8274, 1.1786], grad_fn=<MvBackward>)
# tensor([6.9465, 1.1906], grad_fn=<MvBackward>)
# tensor([7.0667, 1.2027], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3361], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3481], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3601], grad_fn=<MvBackward>)
# tensor([1.5953, 0.3721], grad_fn=<MvBackward>)
# tensor([1.6337, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9842, 0.4802], grad_fn=<MvBackward>)
# tensor([2.0334, 0.4922], grad_fn=<MvBackward>)
# tensor([2.0838, 0.5042], grad_fn=<MvBackward>)
# tensor([2.1354, 0.5162], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5282], grad_fn=<MvBackward>)
# tensor([2.2423, 0.5402], grad_fn=<MvBackward>)
# tensor([2.2975, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3539, 0.5642], grad_fn=<MvBackward>)
# tensor([2.4115, 0.5763], grad_fn=<MvBackward>)
# tensor([2.4704, 0.5883], grad_fn=<MvBackward>)
# tensor([2.5304, 0.6003], grad_fn=<MvBackward>)
# tensor([2.5916, 0.6123], grad_fn=<MvBackward>)
# tensor([2.6540, 0.6243], grad_fn=<MvBackward>)
# tensor([2.7177, 0.6364], grad_fn=<MvBackward>)
# tensor([2.7825, 0.6484], grad_fn=<MvBackward>)
# tensor([2.8486, 0.6604], grad_fn=<MvBackward>)
# tensor([2.9158, 0.6724], grad_fn=<MvBackward>)
# tensor([2.9843, 0.6844], grad_fn=<MvBackward>)
# tensor([3.0539, 0.6965], grad_fn=<MvBackward>)
# tensor([3.1247, 0.7085], grad_fn=<MvBackward>)
# tensor([3.1968, 0.7205], grad_fn=<MvBackward>)
# tensor([3.2701, 0.7326], grad_fn=<MvBackward>)
# tensor([3.3445, 0.7446], grad_fn=<MvBackward>)
# tensor([3.4202, 0.7566], grad_fn=<MvBackward>)
# tensor([3.4970, 0.7686], grad_fn=<MvBackward>)
# tensor([3.5751, 0.7807], grad_fn=<MvBackward>)
# tensor([3.6544, 0.7927], grad_fn=<MvBackward>)
# tensor([3.7349, 0.8047], grad_fn=<MvBackward>)
# tensor([3.8165, 0.8168], grad_fn=<MvBackward>)
# tensor([3.8994, 0.8288], grad_fn=<MvBackward>)
# tensor([3.9835, 0.8409], grad_fn=<MvBackward>)
# tensor([4.0688, 0.8529], grad_fn=<MvBackward>)
# tensor([4.1553, 0.8649], grad_fn=<MvBackward>)
# tensor([4.2430, 0.8770], grad_fn=<MvBackward>)
# tensor([4.3319, 0.8890], grad_fn=<MvBackward>)
# tensor([4.4220, 0.9011], grad_fn=<MvBackward>)
# tensor([4.5133, 0.9131], grad_fn=<MvBackward>)
# tensor([4.6058, 0.9251], grad_fn=<MvBackward>)
# tensor([4.6995, 0.9372], grad_fn=<MvBackward>)
# tensor([4.7945, 0.9492], grad_fn=<MvBackward>)
# tensor([4.8906, 0.9613], grad_fn=<MvBackward>)
# tensor([4.9879, 0.9733], grad_fn=<MvBackward>)
# tensor([5.0865, 0.9854], grad_fn=<MvBackward>)
# tensor([5.1862, 0.9975], grad_fn=<MvBackward>)
# tensor([5.2872, 1.0095], grad_fn=<MvBackward>)
# tensor([5.3893, 1.0216], grad_fn=<MvBackward>)
# tensor([5.4927, 1.0336], grad_fn=<MvBackward>)
# tensor([5.5972, 1.0457], grad_fn=<MvBackward>)
# tensor([5.7030, 1.0577], grad_fn=<MvBackward>)
# tensor([5.8100, 1.0698], grad_fn=<MvBackward>)
# tensor([5.9182, 1.0819], grad_fn=<MvBackward>)
# tensor([6.0276, 1.0939], grad_fn=<MvBackward>)
# tensor([6.1382, 1.1060], grad_fn=<MvBackward>)
# tensor([6.2500, 1.1181], grad_fn=<MvBackward>)
# tensor([6.3630, 1.1301], grad_fn=<MvBackward>)
# tensor([6.4772, 1.1422], grad_fn=<MvBackward>)
# tensor([6.5927, 1.1543], grad_fn=<MvBackward>)
# tensor([6.7093, 1.1664], grad_fn=<MvBackward>)
# tensor([6.8271, 1.1784], grad_fn=<MvBackward>)
# tensor([6.9462, 1.1905], grad_fn=<MvBackward>)
# tensor([7.0664, 1.2026], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3721], grad_fn=<MvBackward>)
# tensor([1.6337, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9841, 0.4801], grad_fn=<MvBackward>)
# tensor([2.0333, 0.4921], grad_fn=<MvBackward>)
# tensor([2.0837, 0.5041], grad_fn=<MvBackward>)
# tensor([2.1354, 0.5161], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5282], grad_fn=<MvBackward>)
# tensor([2.2422, 0.5402], grad_fn=<MvBackward>)
# tensor([2.2974, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3538, 0.5642], grad_fn=<MvBackward>)
# tensor([2.4115, 0.5762], grad_fn=<MvBackward>)
# tensor([2.4703, 0.5882], grad_fn=<MvBackward>)
# tensor([2.5303, 0.6002], grad_fn=<MvBackward>)
# tensor([2.5915, 0.6122], grad_fn=<MvBackward>)
# tensor([2.6539, 0.6243], grad_fn=<MvBackward>)
# tensor([2.7176, 0.6363], grad_fn=<MvBackward>)
# tensor([2.7824, 0.6483], grad_fn=<MvBackward>)
# tensor([2.8484, 0.6603], grad_fn=<MvBackward>)
# tensor([2.9157, 0.6723], grad_fn=<MvBackward>)
# tensor([2.9841, 0.6843], grad_fn=<MvBackward>)
# tensor([3.0537, 0.6964], grad_fn=<MvBackward>)
# tensor([3.1246, 0.7084], grad_fn=<MvBackward>)
# tensor([3.1966, 0.7204], grad_fn=<MvBackward>)
# tensor([3.2699, 0.7324], grad_fn=<MvBackward>)
# tensor([3.3443, 0.7444], grad_fn=<MvBackward>)
# tensor([3.4199, 0.7565], grad_fn=<MvBackward>)
# tensor([3.4968, 0.7685], grad_fn=<MvBackward>)
# tensor([3.5748, 0.7805], grad_fn=<MvBackward>)
# tensor([3.6541, 0.7925], grad_fn=<MvBackward>)
# tensor([3.7346, 0.8046], grad_fn=<MvBackward>)
# tensor([3.8162, 0.8166], grad_fn=<MvBackward>)
# tensor([3.8991, 0.8286], grad_fn=<MvBackward>)
# tensor([3.9831, 0.8406], grad_fn=<MvBackward>)
# tensor([4.0684, 0.8527], grad_fn=<MvBackward>)
# tensor([4.1549, 0.8647], grad_fn=<MvBackward>)
# tensor([4.2425, 0.8767], grad_fn=<MvBackward>)
# tensor([4.3314, 0.8888], grad_fn=<MvBackward>)
# tensor([4.4215, 0.9008], grad_fn=<MvBackward>)
# tensor([4.5128, 0.9128], grad_fn=<MvBackward>)
# tensor([4.6053, 0.9248], grad_fn=<MvBackward>)
# tensor([4.6990, 0.9369], grad_fn=<MvBackward>)
# tensor([4.7938, 0.9489], grad_fn=<MvBackward>)
# tensor([4.8899, 0.9610], grad_fn=<MvBackward>)
# tensor([4.9872, 0.9730], grad_fn=<MvBackward>)
# tensor([5.0857, 0.9850], grad_fn=<MvBackward>)
# tensor([5.1854, 0.9971], grad_fn=<MvBackward>)
# tensor([5.2864, 1.0091], grad_fn=<MvBackward>)
# tensor([5.3885, 1.0211], grad_fn=<MvBackward>)
# tensor([5.4918, 1.0332], grad_fn=<MvBackward>)
# tensor([5.5963, 1.0452], grad_fn=<MvBackward>)
# tensor([5.7020, 1.0573], grad_fn=<MvBackward>)
# tensor([5.8090, 1.0693], grad_fn=<MvBackward>)
# tensor([5.9171, 1.0814], grad_fn=<MvBackward>)
# tensor([6.0265, 1.0934], grad_fn=<MvBackward>)
# tensor([6.1370, 1.1055], grad_fn=<MvBackward>)
# tensor([6.2487, 1.1175], grad_fn=<MvBackward>)
# tensor([6.3617, 1.1296], grad_fn=<MvBackward>)
# tensor([6.4759, 1.1416], grad_fn=<MvBackward>)
# tensor([6.5912, 1.1537], grad_fn=<MvBackward>)
# tensor([6.7078, 1.1657], grad_fn=<MvBackward>)
# tensor([6.8256, 1.1778], grad_fn=<MvBackward>)
# tensor([6.9446, 1.1898], grad_fn=<MvBackward>)
# tensor([7.0648, 1.2019], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3721], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9841, 0.4801], grad_fn=<MvBackward>)
# tensor([2.0333, 0.4921], grad_fn=<MvBackward>)
# tensor([2.0837, 0.5041], grad_fn=<MvBackward>)
# tensor([2.1354, 0.5161], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5281], grad_fn=<MvBackward>)
# tensor([2.2422, 0.5402], grad_fn=<MvBackward>)
# tensor([2.2974, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3538, 0.5642], grad_fn=<MvBackward>)
# tensor([2.4114, 0.5762], grad_fn=<MvBackward>)
# tensor([2.4703, 0.5882], grad_fn=<MvBackward>)
# tensor([2.5303, 0.6002], grad_fn=<MvBackward>)
# tensor([2.5915, 0.6122], grad_fn=<MvBackward>)
# tensor([2.6539, 0.6242], grad_fn=<MvBackward>)
# tensor([2.7176, 0.6363], grad_fn=<MvBackward>)
# tensor([2.7824, 0.6483], grad_fn=<MvBackward>)
# tensor([2.8484, 0.6603], grad_fn=<MvBackward>)
# tensor([2.9156, 0.6723], grad_fn=<MvBackward>)
# tensor([2.9841, 0.6843], grad_fn=<MvBackward>)
# tensor([3.0537, 0.6963], grad_fn=<MvBackward>)
# tensor([3.1245, 0.7084], grad_fn=<MvBackward>)
# tensor([3.1966, 0.7204], grad_fn=<MvBackward>)
# tensor([3.2698, 0.7324], grad_fn=<MvBackward>)
# tensor([3.3443, 0.7444], grad_fn=<MvBackward>)
# tensor([3.4199, 0.7564], grad_fn=<MvBackward>)
# tensor([3.4968, 0.7685], grad_fn=<MvBackward>)
# tensor([3.5748, 0.7805], grad_fn=<MvBackward>)
# tensor([3.6541, 0.7925], grad_fn=<MvBackward>)
# tensor([3.7345, 0.8045], grad_fn=<MvBackward>)
# tensor([3.8162, 0.8166], grad_fn=<MvBackward>)
# tensor([3.8990, 0.8286], grad_fn=<MvBackward>)
# tensor([3.9831, 0.8406], grad_fn=<MvBackward>)
# tensor([4.0683, 0.8526], grad_fn=<MvBackward>)
# tensor([4.1548, 0.8647], grad_fn=<MvBackward>)
# tensor([4.2425, 0.8767], grad_fn=<MvBackward>)
# tensor([4.3314, 0.8887], grad_fn=<MvBackward>)
# tensor([4.4214, 0.9007], grad_fn=<MvBackward>)
# tensor([4.5127, 0.9128], grad_fn=<MvBackward>)
# tensor([4.6052, 0.9248], grad_fn=<MvBackward>)
# tensor([4.6989, 0.9368], grad_fn=<MvBackward>)
# tensor([4.7938, 0.9489], grad_fn=<MvBackward>)
# tensor([4.8898, 0.9609], grad_fn=<MvBackward>)
# tensor([4.9871, 0.9729], grad_fn=<MvBackward>)
# tensor([5.0856, 0.9850], grad_fn=<MvBackward>)
# tensor([5.1853, 0.9970], grad_fn=<MvBackward>)
# tensor([5.2862, 1.0090], grad_fn=<MvBackward>)
# tensor([5.3883, 1.0211], grad_fn=<MvBackward>)
# tensor([5.4917, 1.0331], grad_fn=<MvBackward>)
# tensor([5.5962, 1.0452], grad_fn=<MvBackward>)
# tensor([5.7019, 1.0572], grad_fn=<MvBackward>)
# tensor([5.8088, 1.0692], grad_fn=<MvBackward>)
# tensor([5.9170, 1.0813], grad_fn=<MvBackward>)
# tensor([6.0263, 1.0933], grad_fn=<MvBackward>)
# tensor([6.1368, 1.1054], grad_fn=<MvBackward>)
# tensor([6.2486, 1.1174], grad_fn=<MvBackward>)
# tensor([6.3615, 1.1295], grad_fn=<MvBackward>)
# tensor([6.4757, 1.1415], grad_fn=<MvBackward>)
# tensor([6.5910, 1.1536], grad_fn=<MvBackward>)
# tensor([6.7076, 1.1656], grad_fn=<MvBackward>)
# tensor([6.8254, 1.1777], grad_fn=<MvBackward>)
# tensor([6.9443, 1.1897], grad_fn=<MvBackward>)
# tensor([7.0645, 1.2018], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3721], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9841, 0.4801], grad_fn=<MvBackward>)
# tensor([2.0333, 0.4921], grad_fn=<MvBackward>)
# tensor([2.0837, 0.5041], grad_fn=<MvBackward>)
# tensor([2.1354, 0.5161], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5281], grad_fn=<MvBackward>)
# tensor([2.2422, 0.5402], grad_fn=<MvBackward>)
# tensor([2.2974, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3538, 0.5642], grad_fn=<MvBackward>)
# tensor([2.4114, 0.5762], grad_fn=<MvBackward>)
# tensor([2.4703, 0.5882], grad_fn=<MvBackward>)
# tensor([2.5303, 0.6002], grad_fn=<MvBackward>)
# tensor([2.5915, 0.6122], grad_fn=<MvBackward>)
# tensor([2.6539, 0.6242], grad_fn=<MvBackward>)
# tensor([2.7176, 0.6363], grad_fn=<MvBackward>)
# tensor([2.7824, 0.6483], grad_fn=<MvBackward>)
# tensor([2.8484, 0.6603], grad_fn=<MvBackward>)
# tensor([2.9156, 0.6723], grad_fn=<MvBackward>)
# tensor([2.9841, 0.6843], grad_fn=<MvBackward>)
# tensor([3.0537, 0.6963], grad_fn=<MvBackward>)
# tensor([3.1245, 0.7084], grad_fn=<MvBackward>)
# tensor([3.1966, 0.7204], grad_fn=<MvBackward>)
# tensor([3.2698, 0.7324], grad_fn=<MvBackward>)
# tensor([3.3443, 0.7444], grad_fn=<MvBackward>)
# tensor([3.4199, 0.7564], grad_fn=<MvBackward>)
# tensor([3.4967, 0.7684], grad_fn=<MvBackward>)
# tensor([3.5748, 0.7805], grad_fn=<MvBackward>)
# tensor([3.6540, 0.7925], grad_fn=<MvBackward>)
# tensor([3.7345, 0.8045], grad_fn=<MvBackward>)
# tensor([3.8161, 0.8165], grad_fn=<MvBackward>)
# tensor([3.8990, 0.8286], grad_fn=<MvBackward>)
# tensor([3.9831, 0.8406], grad_fn=<MvBackward>)
# tensor([4.0683, 0.8526], grad_fn=<MvBackward>)
# tensor([4.1548, 0.8646], grad_fn=<MvBackward>)
# tensor([4.2425, 0.8767], grad_fn=<MvBackward>)
# tensor([4.3313, 0.8887], grad_fn=<MvBackward>)
# tensor([4.4214, 0.9007], grad_fn=<MvBackward>)
# tensor([4.5127, 0.9128], grad_fn=<MvBackward>)
# tensor([4.6051, 0.9248], grad_fn=<MvBackward>)
# tensor([4.6988, 0.9368], grad_fn=<MvBackward>)
# tensor([4.7937, 0.9488], grad_fn=<MvBackward>)
# tensor([4.8898, 0.9609], grad_fn=<MvBackward>)
# tensor([4.9871, 0.9729], grad_fn=<MvBackward>)
# tensor([5.0856, 0.9849], grad_fn=<MvBackward>)
# tensor([5.1853, 0.9970], grad_fn=<MvBackward>)
# tensor([5.2862, 1.0090], grad_fn=<MvBackward>)
# tensor([5.3883, 1.0211], grad_fn=<MvBackward>)
# tensor([5.4916, 1.0331], grad_fn=<MvBackward>)
# tensor([5.5961, 1.0451], grad_fn=<MvBackward>)
# tensor([5.7018, 1.0572], grad_fn=<MvBackward>)
# tensor([5.8088, 1.0692], grad_fn=<MvBackward>)
# tensor([5.9169, 1.0813], grad_fn=<MvBackward>)
# tensor([6.0262, 1.0933], grad_fn=<MvBackward>)
# tensor([6.1367, 1.1053], grad_fn=<MvBackward>)
# tensor([6.2485, 1.1174], grad_fn=<MvBackward>)
# tensor([6.3614, 1.1294], grad_fn=<MvBackward>)
# tensor([6.4756, 1.1415], grad_fn=<MvBackward>)
# tensor([6.5909, 1.1535], grad_fn=<MvBackward>)
# tensor([6.7075, 1.1656], grad_fn=<MvBackward>)
# tensor([6.8253, 1.1776], grad_fn=<MvBackward>)
# tensor([6.9442, 1.1897], grad_fn=<MvBackward>)
# tensor([7.0644, 1.2017], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3721], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9841, 0.4801], grad_fn=<MvBackward>)
# tensor([2.0333, 0.4921], grad_fn=<MvBackward>)
# tensor([2.0837, 0.5041], grad_fn=<MvBackward>)
# tensor([2.1354, 0.5161], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5281], grad_fn=<MvBackward>)
# tensor([2.2422, 0.5402], grad_fn=<MvBackward>)
# tensor([2.2974, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3538, 0.5642], grad_fn=<MvBackward>)
# tensor([2.4114, 0.5762], grad_fn=<MvBackward>)
# tensor([2.4703, 0.5882], grad_fn=<MvBackward>)
# tensor([2.5303, 0.6002], grad_fn=<MvBackward>)
# tensor([2.5915, 0.6122], grad_fn=<MvBackward>)
# tensor([2.6539, 0.6242], grad_fn=<MvBackward>)
# tensor([2.7175, 0.6362], grad_fn=<MvBackward>)
# tensor([2.7824, 0.6483], grad_fn=<MvBackward>)
# tensor([2.8484, 0.6603], grad_fn=<MvBackward>)
# tensor([2.9156, 0.6723], grad_fn=<MvBackward>)
# tensor([2.9841, 0.6843], grad_fn=<MvBackward>)
# tensor([3.0537, 0.6963], grad_fn=<MvBackward>)
# tensor([3.1245, 0.7083], grad_fn=<MvBackward>)
# tensor([3.1966, 0.7204], grad_fn=<MvBackward>)
# tensor([3.2698, 0.7324], grad_fn=<MvBackward>)
# tensor([3.3442, 0.7444], grad_fn=<MvBackward>)
# tensor([3.4199, 0.7564], grad_fn=<MvBackward>)
# tensor([3.4967, 0.7684], grad_fn=<MvBackward>)
# tensor([3.5748, 0.7805], grad_fn=<MvBackward>)
# tensor([3.6540, 0.7925], grad_fn=<MvBackward>)
# tensor([3.7345, 0.8045], grad_fn=<MvBackward>)
# tensor([3.8161, 0.8165], grad_fn=<MvBackward>)
# tensor([3.8990, 0.8285], grad_fn=<MvBackward>)
# tensor([3.9830, 0.8406], grad_fn=<MvBackward>)
# tensor([4.0683, 0.8526], grad_fn=<MvBackward>)
# tensor([4.1548, 0.8646], grad_fn=<MvBackward>)
# tensor([4.2424, 0.8766], grad_fn=<MvBackward>)
# tensor([4.3313, 0.8887], grad_fn=<MvBackward>)
# tensor([4.4214, 0.9007], grad_fn=<MvBackward>)
# tensor([4.5126, 0.9127], grad_fn=<MvBackward>)
# tensor([4.6051, 0.9248], grad_fn=<MvBackward>)
# tensor([4.6988, 0.9368], grad_fn=<MvBackward>)
# tensor([4.7937, 0.9488], grad_fn=<MvBackward>)
# tensor([4.8898, 0.9609], grad_fn=<MvBackward>)
# tensor([4.9870, 0.9729], grad_fn=<MvBackward>)
# tensor([5.0855, 0.9849], grad_fn=<MvBackward>)
# tensor([5.1852, 0.9970], grad_fn=<MvBackward>)
# tensor([5.2861, 1.0090], grad_fn=<MvBackward>)
# tensor([5.3882, 1.0210], grad_fn=<MvBackward>)
# tensor([5.4915, 1.0331], grad_fn=<MvBackward>)
# tensor([5.5961, 1.0451], grad_fn=<MvBackward>)
# tensor([5.7018, 1.0571], grad_fn=<MvBackward>)
# tensor([5.8087, 1.0692], grad_fn=<MvBackward>)
# tensor([5.9168, 1.0812], grad_fn=<MvBackward>)
# tensor([6.0261, 1.0933], grad_fn=<MvBackward>)
# tensor([6.1367, 1.1053], grad_fn=<MvBackward>)
# tensor([6.2484, 1.1174], grad_fn=<MvBackward>)
# tensor([6.3613, 1.1294], grad_fn=<MvBackward>)
# tensor([6.4755, 1.1414], grad_fn=<MvBackward>)
# tensor([6.5908, 1.1535], grad_fn=<MvBackward>)
# tensor([6.7074, 1.1655], grad_fn=<MvBackward>)
# tensor([6.8251, 1.1776], grad_fn=<MvBackward>)
# tensor([6.9441, 1.1896], grad_fn=<MvBackward>)
# tensor([7.0643, 1.2017], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3720], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9841, 0.4801], grad_fn=<MvBackward>)
# tensor([2.0333, 0.4921], grad_fn=<MvBackward>)
# tensor([2.0837, 0.5041], grad_fn=<MvBackward>)
# tensor([2.1353, 0.5161], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5281], grad_fn=<MvBackward>)
# tensor([2.2422, 0.5401], grad_fn=<MvBackward>)
# tensor([2.2974, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3538, 0.5642], grad_fn=<MvBackward>)
# tensor([2.4114, 0.5762], grad_fn=<MvBackward>)
# tensor([2.4702, 0.5882], grad_fn=<MvBackward>)
# tensor([2.5303, 0.6002], grad_fn=<MvBackward>)
# tensor([2.5915, 0.6122], grad_fn=<MvBackward>)
# tensor([2.6539, 0.6242], grad_fn=<MvBackward>)
# tensor([2.7175, 0.6362], grad_fn=<MvBackward>)
# tensor([2.7824, 0.6483], grad_fn=<MvBackward>)
# tensor([2.8484, 0.6603], grad_fn=<MvBackward>)
# tensor([2.9156, 0.6723], grad_fn=<MvBackward>)
# tensor([2.9840, 0.6843], grad_fn=<MvBackward>)
# tensor([3.0537, 0.6963], grad_fn=<MvBackward>)
# tensor([3.1245, 0.7083], grad_fn=<MvBackward>)
# tensor([3.1965, 0.7204], grad_fn=<MvBackward>)
# tensor([3.2698, 0.7324], grad_fn=<MvBackward>)
# tensor([3.3442, 0.7444], grad_fn=<MvBackward>)
# tensor([3.4199, 0.7564], grad_fn=<MvBackward>)
# tensor([3.4967, 0.7684], grad_fn=<MvBackward>)
# tensor([3.5748, 0.7804], grad_fn=<MvBackward>)
# tensor([3.6540, 0.7925], grad_fn=<MvBackward>)
# tensor([3.7344, 0.8045], grad_fn=<MvBackward>)
# tensor([3.8161, 0.8165], grad_fn=<MvBackward>)
# tensor([3.8990, 0.8285], grad_fn=<MvBackward>)
# tensor([3.9830, 0.8406], grad_fn=<MvBackward>)
# tensor([4.0683, 0.8526], grad_fn=<MvBackward>)
# tensor([4.1547, 0.8646], grad_fn=<MvBackward>)
# tensor([4.2424, 0.8766], grad_fn=<MvBackward>)
# tensor([4.3313, 0.8887], grad_fn=<MvBackward>)
# tensor([4.4213, 0.9007], grad_fn=<MvBackward>)
# tensor([4.5126, 0.9127], grad_fn=<MvBackward>)
# tensor([4.6051, 0.9247], grad_fn=<MvBackward>)
# tensor([4.6987, 0.9368], grad_fn=<MvBackward>)
# tensor([4.7936, 0.9488], grad_fn=<MvBackward>)
# tensor([4.8897, 0.9608], grad_fn=<MvBackward>)
# tensor([4.9870, 0.9729], grad_fn=<MvBackward>)
# tensor([5.0855, 0.9849], grad_fn=<MvBackward>)
# tensor([5.1852, 0.9969], grad_fn=<MvBackward>)
# tensor([5.2861, 1.0090], grad_fn=<MvBackward>)
# tensor([5.3882, 1.0210], grad_fn=<MvBackward>)
# tensor([5.4915, 1.0330], grad_fn=<MvBackward>)
# tensor([5.5960, 1.0451], grad_fn=<MvBackward>)
# tensor([5.7017, 1.0571], grad_fn=<MvBackward>)
# tensor([5.8086, 1.0691], grad_fn=<MvBackward>)
# tensor([5.9167, 1.0812], grad_fn=<MvBackward>)
# tensor([6.0261, 1.0932], grad_fn=<MvBackward>)
# tensor([6.1366, 1.1053], grad_fn=<MvBackward>)
# tensor([6.2483, 1.1173], grad_fn=<MvBackward>)
# tensor([6.3612, 1.1294], grad_fn=<MvBackward>)
# tensor([6.4754, 1.1414], grad_fn=<MvBackward>)
# tensor([6.5907, 1.1534], grad_fn=<MvBackward>)
# tensor([6.7073, 1.1655], grad_fn=<MvBackward>)
# tensor([6.8250, 1.1775], grad_fn=<MvBackward>)
# tensor([6.9440, 1.1896], grad_fn=<MvBackward>)
# tensor([7.0642, 1.2016], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3720], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6733, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9841, 0.4801], grad_fn=<MvBackward>)
# tensor([2.0333, 0.4921], grad_fn=<MvBackward>)
# tensor([2.0837, 0.5041], grad_fn=<MvBackward>)
# tensor([2.1353, 0.5161], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5281], grad_fn=<MvBackward>)
# tensor([2.2422, 0.5401], grad_fn=<MvBackward>)
# tensor([2.2974, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3538, 0.5642], grad_fn=<MvBackward>)
# tensor([2.4114, 0.5762], grad_fn=<MvBackward>)
# tensor([2.4702, 0.5882], grad_fn=<MvBackward>)
# tensor([2.5303, 0.6002], grad_fn=<MvBackward>)
# tensor([2.5915, 0.6122], grad_fn=<MvBackward>)
# tensor([2.6539, 0.6242], grad_fn=<MvBackward>)
# tensor([2.7175, 0.6362], grad_fn=<MvBackward>)
# tensor([2.7824, 0.6483], grad_fn=<MvBackward>)
# tensor([2.8484, 0.6603], grad_fn=<MvBackward>)
# tensor([2.9156, 0.6723], grad_fn=<MvBackward>)
# tensor([2.9840, 0.6843], grad_fn=<MvBackward>)
# tensor([3.0537, 0.6963], grad_fn=<MvBackward>)
# tensor([3.1245, 0.7083], grad_fn=<MvBackward>)
# tensor([3.1965, 0.7203], grad_fn=<MvBackward>)
# tensor([3.2698, 0.7324], grad_fn=<MvBackward>)
# tensor([3.3442, 0.7444], grad_fn=<MvBackward>)
# tensor([3.4198, 0.7564], grad_fn=<MvBackward>)
# tensor([3.4967, 0.7684], grad_fn=<MvBackward>)
# tensor([3.5747, 0.7804], grad_fn=<MvBackward>)
# tensor([3.6540, 0.7925], grad_fn=<MvBackward>)
# tensor([3.7344, 0.8045], grad_fn=<MvBackward>)
# tensor([3.8161, 0.8165], grad_fn=<MvBackward>)
# tensor([3.8989, 0.8285], grad_fn=<MvBackward>)
# tensor([3.9830, 0.8405], grad_fn=<MvBackward>)
# tensor([4.0682, 0.8526], grad_fn=<MvBackward>)
# tensor([4.1547, 0.8646], grad_fn=<MvBackward>)
# tensor([4.2424, 0.8766], grad_fn=<MvBackward>)
# tensor([4.3312, 0.8886], grad_fn=<MvBackward>)
# tensor([4.4213, 0.9007], grad_fn=<MvBackward>)
# tensor([4.5126, 0.9127], grad_fn=<MvBackward>)
# tensor([4.6050, 0.9247], grad_fn=<MvBackward>)
# tensor([4.6987, 0.9367], grad_fn=<MvBackward>)
# tensor([4.7936, 0.9488], grad_fn=<MvBackward>)
# tensor([4.8897, 0.9608], grad_fn=<MvBackward>)
# tensor([4.9869, 0.9728], grad_fn=<MvBackward>)
# tensor([5.0854, 0.9849], grad_fn=<MvBackward>)
# tensor([5.1851, 0.9969], grad_fn=<MvBackward>)
# tensor([5.2860, 1.0089], grad_fn=<MvBackward>)
# tensor([5.3881, 1.0210], grad_fn=<MvBackward>)
# tensor([5.4914, 1.0330], grad_fn=<MvBackward>)
# tensor([5.5959, 1.0450], grad_fn=<MvBackward>)
# tensor([5.7016, 1.0571], grad_fn=<MvBackward>)
# tensor([5.8085, 1.0691], grad_fn=<MvBackward>)
# tensor([5.9167, 1.0812], grad_fn=<MvBackward>)
# tensor([6.0260, 1.0932], grad_fn=<MvBackward>)
# tensor([6.1365, 1.1052], grad_fn=<MvBackward>)
# tensor([6.2482, 1.1173], grad_fn=<MvBackward>)
# tensor([6.3612, 1.1293], grad_fn=<MvBackward>)
# tensor([6.4753, 1.1414], grad_fn=<MvBackward>)
# tensor([6.5906, 1.1534], grad_fn=<MvBackward>)
# tensor([6.7072, 1.1654], grad_fn=<MvBackward>)
# tensor([6.8249, 1.1775], grad_fn=<MvBackward>)
# tensor([6.9439, 1.1895], grad_fn=<MvBackward>)
# tensor([7.0640, 1.2016], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3720], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3841], grad_fn=<MvBackward>)
# tensor([1.6732, 0.3961], grad_fn=<MvBackward>)
# tensor([1.7141, 0.4081], grad_fn=<MvBackward>)
# tensor([1.7561, 0.4201], grad_fn=<MvBackward>)
# tensor([1.7993, 0.4321], grad_fn=<MvBackward>)
# tensor([1.8437, 0.4441], grad_fn=<MvBackward>)
# tensor([1.8893, 0.4561], grad_fn=<MvBackward>)
# tensor([1.9361, 0.4681], grad_fn=<MvBackward>)
# tensor([1.9841, 0.4801], grad_fn=<MvBackward>)
# tensor([2.0333, 0.4921], grad_fn=<MvBackward>)
# tensor([2.0837, 0.5041], grad_fn=<MvBackward>)
# tensor([2.1353, 0.5161], grad_fn=<MvBackward>)
# tensor([2.1882, 0.5281], grad_fn=<MvBackward>)
# tensor([2.2422, 0.5401], grad_fn=<MvBackward>)
# tensor([2.2974, 0.5522], grad_fn=<MvBackward>)
# tensor([2.3538, 0.5642], grad_fn=<MvBackward>)
# tensor([2.4114, 0.5762], grad_fn=<MvBackward>)
# tensor([2.4702, 0.5882], grad_fn=<MvBackward>)
# tensor([2.5303, 0.6002], grad_fn=<MvBackward>)
# tensor([2.5915, 0.6122], grad_fn=<MvBackward>)
# tensor([2.6539, 0.6242], grad_fn=<MvBackward>)
# tensor([2.7175, 0.6362], grad_fn=<MvBackward>)
# tensor([2.7823, 0.6482], grad_fn=<MvBackward>)
# tensor([2.8484, 0.6603], grad_fn=<MvBackward>)
# tensor([2.9156, 0.6723], grad_fn=<MvBackward>)
# tensor([2.9840, 0.6843], grad_fn=<MvBackward>)
# tensor([3.0537, 0.6963], grad_fn=<MvBackward>)
# tensor([3.1245, 0.7083], grad_fn=<MvBackward>)
# tensor([3.1965, 0.7203], grad_fn=<MvBackward>)
# tensor([3.2698, 0.7323], grad_fn=<MvBackward>)
# tensor([3.3442, 0.7444], grad_fn=<MvBackward>)
# tensor([3.4198, 0.7564], grad_fn=<MvBackward>)
# tensor([3.4967, 0.7684], grad_fn=<MvBackward>)
# tensor([3.5747, 0.7804], grad_fn=<MvBackward>)
# tensor([3.6540, 0.7924], grad_fn=<MvBackward>)
# tensor([3.7344, 0.8045], grad_fn=<MvBackward>)
# tensor([3.8160, 0.8165], grad_fn=<MvBackward>)
# tensor([3.8989, 0.8285], grad_fn=<MvBackward>)
# tensor([3.9830, 0.8405], grad_fn=<MvBackward>)
# tensor([4.0682, 0.8525], grad_fn=<MvBackward>)
# tensor([4.1547, 0.8646], grad_fn=<MvBackward>)
# tensor([4.2423, 0.8766], grad_fn=<MvBackward>)
# tensor([4.3312, 0.8886], grad_fn=<MvBackward>)
# tensor([4.4213, 0.9006], grad_fn=<MvBackward>)
# tensor([4.5125, 0.9127], grad_fn=<MvBackward>)
# tensor([4.6050, 0.9247], grad_fn=<MvBackward>)
# tensor([4.6987, 0.9367], grad_fn=<MvBackward>)
# tensor([4.7935, 0.9488], grad_fn=<MvBackward>)
# tensor([4.8896, 0.9608], grad_fn=<MvBackward>)
# tensor([4.9869, 0.9728], grad_fn=<MvBackward>)
# tensor([5.0854, 0.9848], grad_fn=<MvBackward>)
# tensor([5.1851, 0.9969], grad_fn=<MvBackward>)
# tensor([5.2860, 1.0089], grad_fn=<MvBackward>)
# tensor([5.3880, 1.0209], grad_fn=<MvBackward>)
# tensor([5.4913, 1.0330], grad_fn=<MvBackward>)
# tensor([5.5958, 1.0450], grad_fn=<MvBackward>)
# tensor([5.7016, 1.0570], grad_fn=<MvBackward>)
# tensor([5.8085, 1.0691], grad_fn=<MvBackward>)
# tensor([5.9166, 1.0811], grad_fn=<MvBackward>)
# tensor([6.0259, 1.0932], grad_fn=<MvBackward>)
# tensor([6.1364, 1.1052], grad_fn=<MvBackward>)
# tensor([6.2481, 1.1172], grad_fn=<MvBackward>)
# tensor([6.3611, 1.1293], grad_fn=<MvBackward>)
# tensor([6.4752, 1.1413], grad_fn=<MvBackward>)
# tensor([6.5905, 1.1534], grad_fn=<MvBackward>)
# tensor([6.7071, 1.1654], grad_fn=<MvBackward>)
# tensor([6.8248, 1.1774], grad_fn=<MvBackward>)
# tensor([6.9438, 1.1895], grad_fn=<MvBackward>)
# tensor([7.0639, 1.2015], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# ...
# tensor([3.2692, 0.7320], grad_fn=<MvBackward>)
# tensor([3.3436, 0.7440], grad_fn=<MvBackward>)
# tensor([3.4192, 0.7560], grad_fn=<MvBackward>)
# tensor([3.4960, 0.7680], grad_fn=<MvBackward>)
# tensor([3.5740, 0.7800], grad_fn=<MvBackward>)
# tensor([3.6532, 0.7920], grad_fn=<MvBackward>)
# tensor([3.7336, 0.8040], grad_fn=<MvBackward>)
# tensor([3.8152, 0.8160], grad_fn=<MvBackward>)
# tensor([3.8980, 0.8280], grad_fn=<MvBackward>)
# tensor([3.9820, 0.8400], grad_fn=<MvBackward>)
# tensor([4.0672, 0.8520], grad_fn=<MvBackward>)
# tensor([4.1536, 0.8640], grad_fn=<MvBackward>)
# tensor([4.2412, 0.8760], grad_fn=<MvBackward>)
# tensor([4.3300, 0.8880], grad_fn=<MvBackward>)
# tensor([4.4200, 0.9000], grad_fn=<MvBackward>)
# tensor([4.5112, 0.9120], grad_fn=<MvBackward>)
# tensor([4.6036, 0.9240], grad_fn=<MvBackward>)
# tensor([4.6972, 0.9360], grad_fn=<MvBackward>)
# tensor([4.7920, 0.9480], grad_fn=<MvBackward>)
# tensor([4.8880, 0.9600], grad_fn=<MvBackward>)
# tensor([4.9852, 0.9720], grad_fn=<MvBackward>)
# tensor([5.0836, 0.9840], grad_fn=<MvBackward>)
# tensor([5.1832, 0.9960], grad_fn=<MvBackward>)
# tensor([5.2840, 1.0080], grad_fn=<MvBackward>)
# tensor([5.3860, 1.0200], grad_fn=<MvBackward>)
# tensor([5.4892, 1.0320], grad_fn=<MvBackward>)
# tensor([5.5936, 1.0440], grad_fn=<MvBackward>)
# tensor([5.6992, 1.0560], grad_fn=<MvBackward>)
# tensor([5.8060, 1.0680], grad_fn=<MvBackward>)
# tensor([5.9140, 1.0800], grad_fn=<MvBackward>)
# tensor([6.0232, 1.0920], grad_fn=<MvBackward>)
# tensor([6.1336, 1.1040], grad_fn=<MvBackward>)
# tensor([6.2452, 1.1160], grad_fn=<MvBackward>)
# tensor([6.3580, 1.1280], grad_fn=<MvBackward>)
# tensor([6.4720, 1.1400], grad_fn=<MvBackward>)
# tensor([6.5872, 1.1520], grad_fn=<MvBackward>)
# tensor([6.7036, 1.1640], grad_fn=<MvBackward>)
# tensor([6.8212, 1.1760], grad_fn=<MvBackward>)
# tensor([6.9400, 1.1880], grad_fn=<MvBackward>)
# tensor([7.0600, 1.2000], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3720], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3840], grad_fn=<MvBackward>)
# tensor([1.6732, 0.3960], grad_fn=<MvBackward>)
# tensor([1.7140, 0.4080], grad_fn=<MvBackward>)
# tensor([1.7560, 0.4200], grad_fn=<MvBackward>)
# tensor([1.7992, 0.4320], grad_fn=<MvBackward>)
# tensor([1.8436, 0.4440], grad_fn=<MvBackward>)
# tensor([1.8892, 0.4560], grad_fn=<MvBackward>)
# tensor([1.9360, 0.4680], grad_fn=<MvBackward>)
# tensor([1.9840, 0.4800], grad_fn=<MvBackward>)
# tensor([2.0332, 0.4920], grad_fn=<MvBackward>)
# tensor([2.0836, 0.5040], grad_fn=<MvBackward>)
# tensor([2.1352, 0.5160], grad_fn=<MvBackward>)
# tensor([2.1880, 0.5280], grad_fn=<MvBackward>)
# tensor([2.2420, 0.5400], grad_fn=<MvBackward>)
# tensor([2.2972, 0.5520], grad_fn=<MvBackward>)
# tensor([2.3536, 0.5640], grad_fn=<MvBackward>)
# tensor([2.4112, 0.5760], grad_fn=<MvBackward>)
# tensor([2.4700, 0.5880], grad_fn=<MvBackward>)
# tensor([2.5300, 0.6000], grad_fn=<MvBackward>)
# tensor([2.5912, 0.6120], grad_fn=<MvBackward>)
# tensor([2.6536, 0.6240], grad_fn=<MvBackward>)
# tensor([2.7172, 0.6360], grad_fn=<MvBackward>)
# tensor([2.7820, 0.6480], grad_fn=<MvBackward>)
# tensor([2.8480, 0.6600], grad_fn=<MvBackward>)
# tensor([2.9152, 0.6720], grad_fn=<MvBackward>)
# tensor([2.9836, 0.6840], grad_fn=<MvBackward>)
# tensor([3.0532, 0.6960], grad_fn=<MvBackward>)
# tensor([3.1240, 0.7080], grad_fn=<MvBackward>)
# tensor([3.1960, 0.7200], grad_fn=<MvBackward>)
# tensor([3.2692, 0.7320], grad_fn=<MvBackward>)
# tensor([3.3436, 0.7440], grad_fn=<MvBackward>)
# tensor([3.4192, 0.7560], grad_fn=<MvBackward>)
# tensor([3.4960, 0.7680], grad_fn=<MvBackward>)
# tensor([3.5740, 0.7800], grad_fn=<MvBackward>)
# tensor([3.6532, 0.7920], grad_fn=<MvBackward>)
# tensor([3.7336, 0.8040], grad_fn=<MvBackward>)
# tensor([3.8152, 0.8160], grad_fn=<MvBackward>)
# tensor([3.8980, 0.8280], grad_fn=<MvBackward>)
# tensor([3.9820, 0.8400], grad_fn=<MvBackward>)
# tensor([4.0672, 0.8520], grad_fn=<MvBackward>)
# tensor([4.1536, 0.8640], grad_fn=<MvBackward>)
# tensor([4.2412, 0.8760], grad_fn=<MvBackward>)
# tensor([4.3300, 0.8880], grad_fn=<MvBackward>)
# tensor([4.4200, 0.9000], grad_fn=<MvBackward>)
# tensor([4.5112, 0.9120], grad_fn=<MvBackward>)
# tensor([4.6036, 0.9240], grad_fn=<MvBackward>)
# tensor([4.6972, 0.9360], grad_fn=<MvBackward>)
# tensor([4.7920, 0.9480], grad_fn=<MvBackward>)
# tensor([4.8880, 0.9600], grad_fn=<MvBackward>)
# tensor([4.9852, 0.9720], grad_fn=<MvBackward>)
# tensor([5.0836, 0.9840], grad_fn=<MvBackward>)
# tensor([5.1832, 0.9960], grad_fn=<MvBackward>)
# tensor([5.2840, 1.0080], grad_fn=<MvBackward>)
# tensor([5.3860, 1.0200], grad_fn=<MvBackward>)
# tensor([5.4892, 1.0320], grad_fn=<MvBackward>)
# tensor([5.5936, 1.0440], grad_fn=<MvBackward>)
# tensor([5.6992, 1.0560], grad_fn=<MvBackward>)
# tensor([5.8060, 1.0680], grad_fn=<MvBackward>)
# tensor([5.9140, 1.0800], grad_fn=<MvBackward>)
# tensor([6.0232, 1.0920], grad_fn=<MvBackward>)
# tensor([6.1336, 1.1040], grad_fn=<MvBackward>)
# tensor([6.2452, 1.1160], grad_fn=<MvBackward>)
# tensor([6.3580, 1.1280], grad_fn=<MvBackward>)
# tensor([6.4720, 1.1400], grad_fn=<MvBackward>)
# tensor([6.5872, 1.1520], grad_fn=<MvBackward>)
# tensor([6.7036, 1.1640], grad_fn=<MvBackward>)
# tensor([6.8212, 1.1760], grad_fn=<MvBackward>)
# tensor([6.9400, 1.1880], grad_fn=<MvBackward>)
# tensor([7.0600, 1.2000], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3720], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3840], grad_fn=<MvBackward>)
# tensor([1.6732, 0.3960], grad_fn=<MvBackward>)
# tensor([1.7140, 0.4080], grad_fn=<MvBackward>)
# tensor([1.7560, 0.4200], grad_fn=<MvBackward>)
# tensor([1.7992, 0.4320], grad_fn=<MvBackward>)
# tensor([1.8436, 0.4440], grad_fn=<MvBackward>)
# tensor([1.8892, 0.4560], grad_fn=<MvBackward>)
# tensor([1.9360, 0.4680], grad_fn=<MvBackward>)
# tensor([1.9840, 0.4800], grad_fn=<MvBackward>)
# tensor([2.0332, 0.4920], grad_fn=<MvBackward>)
# tensor([2.0836, 0.5040], grad_fn=<MvBackward>)
# tensor([2.1352, 0.5160], grad_fn=<MvBackward>)
# tensor([2.1880, 0.5280], grad_fn=<MvBackward>)
# tensor([2.2420, 0.5400], grad_fn=<MvBackward>)
# tensor([2.2972, 0.5520], grad_fn=<MvBackward>)
# tensor([2.3536, 0.5640], grad_fn=<MvBackward>)
# tensor([2.4112, 0.5760], grad_fn=<MvBackward>)
# tensor([2.4700, 0.5880], grad_fn=<MvBackward>)
# tensor([2.5300, 0.6000], grad_fn=<MvBackward>)
# tensor([2.5912, 0.6120], grad_fn=<MvBackward>)
# tensor([2.6536, 0.6240], grad_fn=<MvBackward>)
# tensor([2.7172, 0.6360], grad_fn=<MvBackward>)
# tensor([2.7820, 0.6480], grad_fn=<MvBackward>)
# tensor([2.8480, 0.6600], grad_fn=<MvBackward>)
# tensor([2.9152, 0.6720], grad_fn=<MvBackward>)
# tensor([2.9836, 0.6840], grad_fn=<MvBackward>)
# tensor([3.0532, 0.6960], grad_fn=<MvBackward>)
# tensor([3.1240, 0.7080], grad_fn=<MvBackward>)
# tensor([3.1960, 0.7200], grad_fn=<MvBackward>)
# tensor([3.2692, 0.7320], grad_fn=<MvBackward>)
# tensor([3.3436, 0.7440], grad_fn=<MvBackward>)
# tensor([3.4192, 0.7560], grad_fn=<MvBackward>)
# tensor([3.4960, 0.7680], grad_fn=<MvBackward>)
# tensor([3.5740, 0.7800], grad_fn=<MvBackward>)
# tensor([3.6532, 0.7920], grad_fn=<MvBackward>)
# tensor([3.7336, 0.8040], grad_fn=<MvBackward>)
# tensor([3.8152, 0.8160], grad_fn=<MvBackward>)
# tensor([3.8980, 0.8280], grad_fn=<MvBackward>)
# tensor([3.9820, 0.8400], grad_fn=<MvBackward>)
# tensor([4.0672, 0.8520], grad_fn=<MvBackward>)
# tensor([4.1536, 0.8640], grad_fn=<MvBackward>)
# tensor([4.2412, 0.8760], grad_fn=<MvBackward>)
# tensor([4.3300, 0.8880], grad_fn=<MvBackward>)
# tensor([4.4200, 0.9000], grad_fn=<MvBackward>)
# tensor([4.5112, 0.9120], grad_fn=<MvBackward>)
# tensor([4.6036, 0.9240], grad_fn=<MvBackward>)
# tensor([4.6972, 0.9360], grad_fn=<MvBackward>)
# tensor([4.7920, 0.9480], grad_fn=<MvBackward>)
# tensor([4.8880, 0.9600], grad_fn=<MvBackward>)
# tensor([4.9852, 0.9720], grad_fn=<MvBackward>)
# tensor([5.0836, 0.9840], grad_fn=<MvBackward>)
# tensor([5.1832, 0.9960], grad_fn=<MvBackward>)
# tensor([5.2840, 1.0080], grad_fn=<MvBackward>)
# tensor([5.3860, 1.0200], grad_fn=<MvBackward>)
# tensor([5.4892, 1.0320], grad_fn=<MvBackward>)
# tensor([5.5936, 1.0440], grad_fn=<MvBackward>)
# tensor([5.6992, 1.0560], grad_fn=<MvBackward>)
# tensor([5.8060, 1.0680], grad_fn=<MvBackward>)
# tensor([5.9140, 1.0800], grad_fn=<MvBackward>)
# tensor([6.0232, 1.0920], grad_fn=<MvBackward>)
# tensor([6.1336, 1.1040], grad_fn=<MvBackward>)
# tensor([6.2452, 1.1160], grad_fn=<MvBackward>)
# tensor([6.3580, 1.1280], grad_fn=<MvBackward>)
# tensor([6.4720, 1.1400], grad_fn=<MvBackward>)
# tensor([6.5872, 1.1520], grad_fn=<MvBackward>)
# tensor([6.7036, 1.1640], grad_fn=<MvBackward>)
# tensor([6.8212, 1.1760], grad_fn=<MvBackward>)
# tensor([6.9400, 1.1880], grad_fn=<MvBackward>)
# tensor([7.0600, 1.2000], grad_fn=<MvBackward>)
# tensor([1.0012, 0.0120], grad_fn=<MvBackward>)
# tensor([1.0036, 0.0240], grad_fn=<MvBackward>)
# tensor([1.0072, 0.0360], grad_fn=<MvBackward>)
# tensor([1.0120, 0.0480], grad_fn=<MvBackward>)
# tensor([1.0180, 0.0600], grad_fn=<MvBackward>)
# tensor([1.0252, 0.0720], grad_fn=<MvBackward>)
# tensor([1.0336, 0.0840], grad_fn=<MvBackward>)
# tensor([1.0432, 0.0960], grad_fn=<MvBackward>)
# tensor([1.0540, 0.1080], grad_fn=<MvBackward>)
# tensor([1.0660, 0.1200], grad_fn=<MvBackward>)
# tensor([1.0792, 0.1320], grad_fn=<MvBackward>)
# tensor([1.0936, 0.1440], grad_fn=<MvBackward>)
# tensor([1.1092, 0.1560], grad_fn=<MvBackward>)
# tensor([1.1260, 0.1680], grad_fn=<MvBackward>)
# tensor([1.1440, 0.1800], grad_fn=<MvBackward>)
# tensor([1.1632, 0.1920], grad_fn=<MvBackward>)
# tensor([1.1836, 0.2040], grad_fn=<MvBackward>)
# tensor([1.2052, 0.2160], grad_fn=<MvBackward>)
# tensor([1.2280, 0.2280], grad_fn=<MvBackward>)
# tensor([1.2520, 0.2400], grad_fn=<MvBackward>)
# tensor([1.2772, 0.2520], grad_fn=<MvBackward>)
# tensor([1.3036, 0.2640], grad_fn=<MvBackward>)
# tensor([1.3312, 0.2760], grad_fn=<MvBackward>)
# tensor([1.3600, 0.2880], grad_fn=<MvBackward>)
# tensor([1.3900, 0.3000], grad_fn=<MvBackward>)
# tensor([1.4212, 0.3120], grad_fn=<MvBackward>)
# tensor([1.4536, 0.3240], grad_fn=<MvBackward>)
# tensor([1.4872, 0.3360], grad_fn=<MvBackward>)
# tensor([1.5220, 0.3480], grad_fn=<MvBackward>)
# tensor([1.5580, 0.3600], grad_fn=<MvBackward>)
# tensor([1.5952, 0.3720], grad_fn=<MvBackward>)
# tensor([1.6336, 0.3840], grad_fn=<MvBackward>)
# tensor([1.6732, 0.3960], grad_fn=<MvBackward>)
# tensor([1.7140, 0.4080], grad_fn=<MvBackward>)
# tensor([1.7560, 0.4200], grad_fn=<MvBackward>)
# tensor([1.7992, 0.4320], grad_fn=<MvBackward>)
# tensor([1.8436, 0.4440], grad_fn=<MvBackward>)
# tensor([1.8892, 0.4560], grad_fn=<MvBackward>)
# tensor([1.9360, 0.4680], grad_fn=<MvBackward>)
# tensor([1.9840, 0.4800], grad_fn=<MvBackward>)
# tensor([2.0332, 0.4920], grad_fn=<MvBackward>)
# tensor([2.0836, 0.5040], grad_fn=<MvBackward>)
# tensor([2.1352, 0.5160], grad_fn=<MvBackward>)
# tensor([2.1880, 0.5280], grad_fn=<MvBackward>)
# tensor([2.2420, 0.5400], grad_fn=<MvBackward>)
# tensor([2.2972, 0.5520], grad_fn=<MvBackward>)
# tensor([2.3536, 0.5640], grad_fn=<MvBackward>)
# tensor([2.4112, 0.5760], grad_fn=<MvBackward>)
# tensor([2.4700, 0.5880], grad_fn=<MvBackward>)
# tensor([2.5300, 0.6000], grad_fn=<MvBackward>)
# tensor([2.5912, 0.6120], grad_fn=<MvBackward>)
# tensor([2.6536, 0.6240], grad_fn=<MvBackward>)
# tensor([2.7172, 0.6360], grad_fn=<MvBackward>)
# tensor([2.7820, 0.6480], grad_fn=<MvBackward>)
# tensor([2.8480, 0.6600], grad_fn=<MvBackward>)
# tensor([2.9152, 0.6720], grad_fn=<MvBackward>)
# tensor([2.9836, 0.6840], grad_fn=<MvBackward>)
# tensor([3.0532, 0.6960], grad_fn=<MvBackward>)
# tensor([3.1240, 0.7080], grad_fn=<MvBackward>)
# tensor([3.1960, 0.7200], grad_fn=<MvBackward>)
# tensor([3.2692, 0.7320], grad_fn=<MvBackward>)
# tensor([3.3436, 0.7440], grad_fn=<MvBackward>)
# tensor([3.4192, 0.7560], grad_fn=<MvBackward>)
# tensor([3.4960, 0.7680], grad_fn=<MvBackward>)
# tensor([3.5740, 0.7800], grad_fn=<MvBackward>)
# tensor([3.6532, 0.7920], grad_fn=<MvBackward>)
# tensor([3.7336, 0.8040], grad_fn=<MvBackward>)
# tensor([3.8152, 0.8160], grad_fn=<MvBackward>)
# tensor([3.8980, 0.8280], grad_fn=<MvBackward>)
# tensor([3.9820, 0.8400], grad_fn=<MvBackward>)
# tensor([4.0672, 0.8520], grad_fn=<MvBackward>)
# tensor([4.1536, 0.8640], grad_fn=<MvBackward>)
# tensor([4.2412, 0.8760], grad_fn=<MvBackward>)
# tensor([4.3300, 0.8880], grad_fn=<MvBackward>)
# tensor([4.4200, 0.9000], grad_fn=<MvBackward>)
# tensor([4.5112, 0.9120], grad_fn=<MvBackward>)
# tensor([4.6036, 0.9240], grad_fn=<MvBackward>)
# tensor([4.6972, 0.9360], grad_fn=<MvBackward>)
# tensor([4.7920, 0.9480], grad_fn=<MvBackward>)
# tensor([4.8880, 0.9600], grad_fn=<MvBackward>)
# tensor([4.9852, 0.9720], grad_fn=<MvBackward>)
# tensor([5.0836, 0.9840], grad_fn=<MvBackward>)
# tensor([5.1832, 0.9960], grad_fn=<MvBackward>)
# tensor([5.2840, 1.0080], grad_fn=<MvBackward>)
# tensor([5.3860, 1.0200], grad_fn=<MvBackward>)
# tensor([5.4892, 1.0320], grad_fn=<MvBackward>)
# tensor([5.5936, 1.0440], grad_fn=<MvBackward>)
# tensor([5.6992, 1.0560], grad_fn=<MvBackward>)
# tensor([5.8060, 1.0680], grad_fn=<MvBackward>)
# tensor([5.9140, 1.0800], grad_fn=<MvBackward>)
# tensor([6.0232, 1.0920], grad_fn=<MvBackward>)
# tensor([6.1336, 1.1040], grad_fn=<MvBackward>)
# tensor([6.2452, 1.1160], grad_fn=<MvBackward>)
# tensor([6.3580, 1.1280], grad_fn=<MvBackward>)
# tensor([6.4720, 1.1400], grad_fn=<MvBackward>)
# tensor([6.5872, 1.1520], grad_fn=<MvBackward>)
# tensor([6.7036, 1.1640], grad_fn=<MvBackward>)
# tensor([6.8212, 1.1760], grad_fn=<MvBackward>)
# tensor([6.9400, 1.1880], grad_fn=<MvBackward>)
# tensor([7.0600, 1.2000], grad_fn=<MvBackward>)
# [50] loss: 51.284

# %% [markdown]
# ## 3. A Better Problem Formulation
#
# Here is a list of things we discussed during the class that could help to make the problem more representative of the reality:
#
# 1. More realistic definition of state and action spaces: Rocket orientation, angular velocity, etc.
# 2. Better dynamical model, e.g., drag
# 3. Constraints in state and action spaces
# 4. Controller design for a distribution of initial states rather than one
# 5. Randomness in dynamics, sensing, etc.
# 6. Discontinuity in modeling so that gradient cannot be computed, e.g., mechanical failures.
#
# In this project, please choose at least one aspect from 1 to 5 from the list to improve your problem formulation and solve the resultant problem. We will address 6 when we talk about reinforcement learning.
#
# Here is one example of problem formulation when we consider randomness in dynamics and initial states:
#
# $$
# \begin{aligned}
# \min_{\theta} \quad & \mathbb{E}_{\{w(t), u(t), x(0)\}}\left[||x(T)||^2\right] \\
# \quad & d(t+1) = d(t) + v(t) + w(t) \Delta t, \\
# \quad & v(t+1) = v(t) + a(t) + u(t) \Delta t, \\
# \quad & a(t) = f_{\theta}(x(t)), ~\forall t=1,...,T-1 \\
# \quad & x(1) \sim \Pr(x(1))
# \end{aligned}
# $$
#
# Here $w(t) \sim \Pr(w(t))$ and $u(t) \sim \Pr(u(t))$ are modeled as i.i.d. noises added to the dynamics, and $\Pr(x(1))$ is the distribution of initial states. We will approximate this problem using samples from $\Pr(w(t))$, $\Pr(u(t))$, and $\Pr(x(1))$. To do so, we sample $\{w(1)^{(i)},w(2)^{(i)},...,w(T)^{(i)}\}_{i}^N$ from $\Pr(w(t))$,  $\{u(1)^{(i)},u(2)^{(i)},...,u(T)^{(i)}\}_{i}^N$ from $\Pr(u(t))$, and $\{x(0)^{(i)}\}_{i}^N$ from $\Pr(x(1))$, where $N$ is the number of samples to be considered. Then we have the following problem instead:
#
# $$
# \begin{aligned}
# \min_{\theta} \quad & \frac{1}{N}\sum_{i=1}^N ||x^{(i)}(T)||^2 \\
# \quad & d(t+1)^{(i)} = d(t)^{(i)} + v(t)^{(i)} + w(t)^{(i)} \Delta t, \\
# \quad & v(t+1)^{(i)} = v(t)^{(i)} + a(t)^{(i)} + u(t)^{(i)} \Delta t, \\
# \quad & a(t)^{(i)} = f_{\theta}(x(t)^{(i)}), ~\forall t=1,...,T-1, ~i=1,...,N \\
# \end{aligned}
# $$
#
# The code up this new problem, you will fully utilize the tensor operations in PyTorch. For example, the state tensor "x" will now become a N-by-2 matrix, where the first dimension represents the number of trajectories to be optimized.

# %% [markdown]
# ## 4. Grading
#
# * (30%) Documentation of the problem formulation: Clearly describe the objective function, the variables, the constraints, and the assumptions involved in formulating the problem.
#
# * (40%) Programming: Like for homeworks, please push you code to your github repo. Please comment your code so that it is useful to you in the future.
#
# * (30%) Analysis of the results: Please document the convergence and the optimal solutions (e.g., the state trajectory if it is a control problem).
#
# * (Bonus 20%) Formulation of a problem different from rocket landing: The PyTorch framework can also be used for other engineering problems, e.g., for structure design with nonlinear mechanical properties. You get 20 bonus points for solving your own problems that are at least at the same level of difficulty as rocket landing.
